# %% [markdown]
# Import Some imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Get the Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Satyam4229/IIT-and-NIT-College-Dataset/main/data.csv")
df.tail()
# Out:
#        year institute_type  round_no quota            pool institute_short  \
# 64953  2021            NIT         1    JK     Female-Only    NIT-Srinagar
# 64954  2021            NIT         1    JK  Gender-Neutral    NIT-Srinagar
# 64955  2021            NIT         1    JK     Female-Only    NIT-Srinagar
# 64956  2021            NIT         1    LA  Gender-Neutral    NIT-Srinagar
# 64957  2021            NIT         1    LA     Female-Only    NIT-Srinagar
#
#                                     program_name program_duration  \
# 64953  Electronics and Communication Engineering          4 Years
# 64954  Electronics and Communication Engineering          4 Years
# 64955  Electronics and Communication Engineering          4 Years
# 64956  Electronics and Communication Engineering          4 Years
# 64957  Electronics and Communication Engineering          4 Years
#
#       degree_short category  opening_rank  closing_rank  is_preparatory  \
# 64953       B.Tech       SC         14185         24048               0
# 64954       B.Tech       ST          2736          4171               0
# 64955       B.Tech       ST         10870         10870               0
# 64956       B.Tech      GEN        166453        265454               0
# 64957       B.Tech      GEN        215054        215054               0
#
#        Unnamed: 13
# 64953          NaN
# 64954          NaN
# 64955          NaN
# 64956          NaN
# 64957          NaN

# %%
del df["Unnamed: 13"]

# %%
df.head()
# Out:
#    year institute_type  round_no quota            pool institute_short  \
# 0  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
# 1  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
# 2  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
# 3  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
# 4  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
#
#             program_name program_duration degree_short category  opening_rank  \
# 0  Aerospace Engineering          4 Years       B.Tech      GEN           838
# 1  Aerospace Engineering          4 Years       B.Tech  OBC-NCL           408
# 2  Aerospace Engineering          4 Years       B.Tech       SC           297
# 3  Aerospace Engineering          4 Years       B.Tech       ST            79
# 4  Aerospace Engineering          4 Years       B.Tech  GEN-PWD            94
#
#    closing_rank  is_preparatory
# 0          1841               0
# 1          1098               0
# 2           468               0
# 3           145               0
# 4            94               0

# %% [markdown]
# Exploring the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64958 entries, 0 to 64957
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              64958 non-null  int64
#  1   institute_type    64958 non-null  object
#  2   round_no          64958 non-null  int64
#  3   quota             64958 non-null  object
#  4   pool              64958 non-null  object
#  5   institute_short   64958 non-null  object
#  6   program_name      64958 non-null  object
#  7   program_duration  64958 non-null  object
#  8   degree_short      64958 non-null  object
#  9   category          64958 non-null  object
#  10  opening_rank      64958 non-null  int64
#  11  closing_rank      64958 non-null  int64
#  12  is_preparatory    64958 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 6.4+ MB

# %%
df.describe()
# Out:
#                year      round_no  opening_rank  closing_rank  is_preparatory
# count  64958.000000  64958.000000  6.495800e+04  6.495800e+04    64958.000000
# mean    2020.421580      2.609348  8.259642e+03  1.070497e+04        0.047631
# std        1.149762      2.422558  2.679448e+04  3.788101e+04        0.212985
# min     2016.000000      1.000000  0.000000e+00  0.000000e+00        0.000000
# 25%     2020.000000      1.000000  6.710000e+02  8.320000e+02        0.000000
# 50%     2021.000000      1.000000  2.309000e+03  2.764500e+03        0.000000
# 75%     2021.000000      6.000000  6.932000e+03  8.190000e+03        0.000000
# max     2021.000000      7.000000  1.082601e+06  1.144790e+06        1.000000

# %%
df.shape
# Out:
# (64958, 13)

# %%
Columns = pd.DataFrame(df.columns)
Columns
# Out:
#                    0
# 0               year
# 1     institute_type
# 2           round_no
# 3              quota
# 4               pool
# 5    institute_short
# 6       program_name
# 7   program_duration
# 8       degree_short
# 9           category
# 10      opening_rank
# 11      closing_rank
# 12    is_preparatory

# %%
Quota = pd.DataFrame(df["quota"].unique())
Quota
# Out:
#     0
# 0  AI
# 1  HS
# 2  OS
# 3  AP
# 4  GO
# 5  JK
# 6  LA

# %%
Institutes = pd.DataFrame(df["institute_short"].unique(), columns = {'Institute':0})
Institutes
# Out:
#                   Institute
# 0                IIT-Bombay
# 1                 IIT-Delhi
# 2             IIT-Kharagpur
# 3                IIT-Kanpur
# 4                IIT-Madras
# 5               IIT-Roorkee
# 6              IIT-Guwahati
# 7                IIT-Indore
# 8             IIT-Hyderabad
# 9        IIT-(BHU) Varanasi
# 10                IIT-Patna
# 11        IIT-(ISM) Dhanbad
# 12          IIT-Bhubaneswar
# 13                IIT-Mandi
# 14          IIT-Gandhinagar
# 15                IIT-Ropar
# 16              IIT-Jodhpur
# 17             IIT-Tirupati
# 18               IIT-Bhilai
# 19              IIT-Dharwad
# 20                  IIT-Goa
# 21                IIT-Jammu
# 22             IIT-Palakkad
# 23             NIT-Warangal
# 24      NIT-Tiruchirappalli
# 25          NIT-Uttarakhand
# 26                NIT-Surat
# 27               NIT-Nagpur
# 28       NIT-Andhra-Pradesh
# 29            NIT-Jalandhar
# 30               NIT-Jaipur
# 31               NIT-Bhopal
# 32            NIT-Allahabad
# 33              NIT-Calicut
# 34             NIT-Agartala
# 35                NIT-Delhi
# 36             NIT-Durgapur
# 37                  NIT-Goa
# 38             NIT-Hamirpur
# 39            NIT-Meghalaya
# 40  NIT-Karnataka-Surathkal
# 41                NIT-Patna
# 42             NIT-Nagaland
# 43           NIT-Puducherry
# 44               NIT-Raipur
# 45               NIT-Sikkim
# 46    NIT-Arunachal-Pradesh
# 47           NIT-Jamshedpur
# 48          NIT-Kurukshetra
# 49              NIT-Manipur
# 50              NIT-Mizoram
# 51             NIT-Rourkela
# 52              NIT-Silchar
# 53             NIT-Srinagar

# %%
Programs = pd.DataFrame(df["program_name"].unique(), columns = {'program':0})
Programs
# Out:
#                                                program
# 0                                Aerospace Engineering
# 1                                 Chemical Engineering
# 2                                            Chemistry
# 3                                    Civil Engineering
# 4                     Computer Science and Engineering
# ..                                                 ...
# 125                           Food Process Engineering
# 126  Ceramic Engineering and M.Tech Industrial Ceramic
# 127                                       Life Science
# 128                       Mathematics and Data Science
# 129                          Computational Mathematics
#
# [130 rows x 1 columns]

# %%
Category = pd.DataFrame(df["category"].unique())
Category
# Out:
#              0
# 0          GEN
# 1      OBC-NCL
# 2           SC
# 3           ST
# 4      GEN-PWD
# 5  OBC-NCL-PWD
# 6       SC-PWD
# 7       ST-PWD
# 8      GEN-EWS
# 9  GEN-EWS-PWD

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis', alpha = 0.5)
# Out:
# <Axes: >

# %%
df.to_csv("Branch-Prediction.csv")

# %% [markdown]
# Evaluation of Model :-
# Evaluate the model & find its error & accuracy rate based on given feature & target value.
# Also find out that how model works when we give it a specific type of data for the prediction.

# %%
eval_College = df
eval_College.head()
# Out:
#    year institute_type  round_no quota            pool institute_short  \
# 0  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
# 1  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
# 2  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
# 3  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
# 4  2016            IIT         6    AI  Gender-Neutral      IIT-Bombay
#
#             program_name program_duration degree_short category  opening_rank  \
# 0  Aerospace Engineering          4 Years       B.Tech      GEN           838
# 1  Aerospace Engineering          4 Years       B.Tech  OBC-NCL           408
# 2  Aerospace Engineering          4 Years       B.Tech       SC           297
# 3  Aerospace Engineering          4 Years       B.Tech       ST            79
# 4  Aerospace Engineering          4 Years       B.Tech  GEN-PWD            94
#
#    closing_rank  is_preparatory
# 0          1841               0
# 1          1098               0
# 2           468               0
# 3           145               0
# 4            94               0

# %% [markdown]
# Convert Object values into numerical :-
# Institute type = IIT-0, NIT-1
# Quota = AI-0, AP-1, GO-2, HS-3, JK-4, LA-5, OS-6
# Category = GEN-0, GEN(EWS)-1, GEN(EWS-PWD)-2, GEN-PWD-3, OBC(NCL)-4, OBC(NCL-PWD)-5 SC-6, SC(PWD)-7, ST-8, ST(PWD)-9

# %%
# Changing Institute type

eval_College['institute_type'] = [0 if x == 'IIT' else 1 for x in eval_College['institute_type']]
eval_College['institute_type'].unique()
# Out:
# array([0, 1])

# %%
# importing library for encoding

from sklearn.preprocessing import LabelEncoder

# %%
# Labeling the quota values

le = LabelEncoder()
eval_College['quota'] = le.fit_transform(eval_College['quota'])
eval_College['quota'].unique()
# Out:
# array([0, 3, 6, 1, 2, 4, 5])

# %%
# Labeling the categories

eval_College['category']= le.fit_transform(eval_College['category'])
eval_College['category'].unique()
# Out:
# array([0, 4, 6, 8, 3, 5, 7, 9, 1, 2])

# %%
# Labeling the Institute values

eval_College['institute_short']= le.fit_transform(eval_College['institute_short'])
eval_College['institute_short'].unique()
# Out:
# array([ 4,  5, 15, 14, 16, 20,  9, 11, 10,  0, 19,  1,  3, 17,  7, 21, 13,
#        22,  2,  6,  8, 12, 18, 53, 51, 52, 50, 42, 25, 34, 33, 27, 24, 28,
#        23, 29, 30, 31, 32, 39, 36, 43, 41, 44, 45, 47, 26, 35, 37, 38, 40,
#        46, 48, 49])

# %%
# Labeling the Program Name values

eval_College['program_name']= le.fit_transform(eval_College['program_name'])
eval_College['program_name'].unique()
# Out:
# array([  0,  28,  31,  32,  42,  47,  51,  52,  64,  66,  67,  98, 101,
#        107, 108, 109,  14,  24,  48,  95, 126, 129,   1,   2,   4,   7,
#         37,  46,  54,  58,  59,  72,  79,  80,  83,  86, 114,  87, 104,
#        110, 116, 118, 122, 127,  20,  45,  90,  97,  18,  19,  65, 117,
#          6,  13,  57,  74,  75, 124,  29,  61,  68,  91,  15,  17,  26,
#         36,  53,  56,  76,  92, 105, 121,   5,  62,  70, 112, 115, 119,
#         33,  34,  99, 100, 120,  35,  49, 103, 111,  10,  71, 102, 106,
#          3,  60,  81,  88,   8,  16,  44,  11,  55,  50,  69,  89,  21,
#          9,  38, 113,  22,  43,  63, 128,  30,  94,  25,  39,  84, 125,
#         41,  93,  82,  78, 123,  23,  12,  77,  73,  27,  85,  96,  40])

# %%
# Labeling the Degree values

eval_College['degree_short']= le.fit_transform(eval_College['degree_short'])
eval_College['degree_short'].unique()
# Out:
# array([ 4,  7,  5, 11,  0, 10,  1,  2,  6, 12,  3,  9,  8])

# %%
# Target data

y = eval_College[['institute_short', 'degree_short', 'program_name']]

# %%
# Featured data

X = eval_College[['category', 'quota']]

# %%
# Spilliting the data into training and testing dataset

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8)

# %%
# Importing library for mdoel generation

from sklearn.neighbors import KNeighborsClassifier

# %%
# Regenerating the model once again

model = KNeighborsClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predicting the model again in numerical terms

y_pred = model.predict(X_test)
y_pred
# Out:
# array([[15,  4, 26],
#        [23,  4, 32],
#        [15,  4, 26],
#        ...,
#        [15,  5, 47],
#        [23,  4, 47],
#        [23,  4, 32]], shape=(12992, 3))

# %%
# Checking the Mean Absolute error of whole model

from sklearn.metrics import mean_absolute_error
print("mean_absolute_error : ", mean_absolute_error(y_pred, y_test))
# Out:
# mean_absolute_error :  14.639932266009852

# %%
# Accuracy for Institute short

from sklearn.metrics import classification_report 
y_pred1 = y_pred[:,0]
y_test1 = y_test.loc[:,"institute_short"]
print(classification_report(y_pred1, y_test1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.37      0.08      0.14      2523
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         0
#            8       0.00      0.00      0.00         0
#            9       0.02      0.03      0.03       151
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         0
#           14       0.18      0.08      0.11      1253
#           15       0.37      0.19      0.25      2279
#           16       0.00      0.11      0.01        19
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.05      0.08      0.06       356
#           21       0.00      0.00      0.00         0
#           22       0.00      0.00      0.00         0
#           23       0.46      0.07      0.12      2215
#           24       0.13      0.06      0.09       645
#           25       0.00      0.00      0.00         0
#           26       0.07      0.02      0.03       507
#           27       0.02      0.06      0.03       103
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           31       0.45      0.10      0.16       667
#           32       0.00      0.00      0.00         0
#           33       0.06      0.03      0.04       505
#           34       0.00      0.00      0.00         0
#           35       0.03      0.04      0.03       164
#           36       0.00      0.14      0.01         7
#           37       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#           39       0.00      0.00      0.00         0
#           40       0.00      0.00      0.00         0
#           41       0.29      0.04      0.06       630
#           42       0.00      0.00      0.00         0
#           43       0.00      0.00      0.00         0
#           44       0.02      0.01      0.02       224
#           45       0.00      0.00      0.00         0
#           46       0.11      0.10      0.11       628
#           47       0.00      0.00      0.00         0
#           48       0.00      0.00      0.00         0
#           49       0.53      1.00      0.69       107
#           50       0.00      0.00      0.00         0
#           51       0.00      0.00      0.00         0
#           52       0.00      0.00      0.00         0
#           53       0.16      1.00      0.28         9
#
#     accuracy                           0.10     12992
#    macro avg       0.06      0.06      0.04     12992
# weighted avg       0.29      0.10      0.13     12992

# %%
mean_absolute_error(y_pred1, y_test1)
# Out:
# 8.52824815270936

# %%
from sklearn.metrics import accuracy_score
Accuracy1 = accuracy_score(y_pred1, y_test1)
Accuracy1
# Out:
# 0.09721366995073892

# %%
# Accuracy for Degree

from sklearn.metrics import classification_report 
y_pred2 = y_pred[:,1]
y_test2 = y_test.loc[:,"degree_short"]
print(classification_report(y_pred2, y_test2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.92      0.82      0.86     11728
#            5       0.20      0.19      0.20      1264
#            6       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         0
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#
#     accuracy                           0.76     12992
#    macro avg       0.09      0.08      0.08     12992
# weighted avg       0.85      0.76      0.80     12992

# %%
mean_absolute_error(y_pred2, y_test2)
# Out:
# 0.5573429802955665

# %%
from sklearn.metrics import accuracy_score
Accuracy2 = accuracy_score(y_pred2, y_test2)
Accuracy2
# Out:
# 0.7570812807881774

# %%
# Accuracy for Program Name 

from sklearn.metrics import classification_report 
y_pred3 = y_pred[:,2]
y_test3 = y_test.loc[:,"program_name"]
print(classification_report(y_pred3, y_test3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            7       0.11      0.02      0.03      1758
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         1
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           22       0.19      0.00      0.01      1305
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00         0
#           25       0.00      0.00      0.00         0
#           26       0.07      0.00      0.01      1015
#           27       0.00      0.00      0.00         0
#           28       0.12      0.07      0.09      1484
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           32       0.18      0.13      0.15      1809
#           33       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         0
#           35       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#           37       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#           39       0.00      0.00      0.00         0
#           40       0.00      0.00      0.00         0
#           41       0.00      0.00      0.00         0
#           42       0.15      0.25      0.19      1023
#           43       0.00      0.00      0.00         0
#           44       0.00      0.00      0.00         0
#           45       0.00      0.00      0.00         0
#           46       0.00      0.00      0.00         0
#           47       0.18      0.09      0.12      2421
#           48       0.00      0.00      0.00         0
#           49       0.00      0.00      0.00         0
#           51       0.00      0.00      0.00         0
#           52       0.00      0.00      0.00         0
#           53       0.00      0.00      0.00         0
#           54       0.00      0.00      0.00         0
#           55       0.02      0.02      0.02       239
#           56       0.00      0.00      0.00         0
#           57       0.08      0.12      0.10       656
#           58       0.00      0.00      0.00         0
#           59       0.00      0.00      0.00         0
#           60       0.00      0.00      0.00         0
#           61       0.00      0.00      0.00         0
#           62       0.00      0.00      0.00         0
#           63       0.00      0.00      0.00         0
#           64       0.00      0.00      0.00         0
#           65       0.00      0.00      0.00         0
#           66       0.00      0.00      0.00         0
#           68       0.00      0.00      0.00         0
#           69       0.00      0.00      0.00         0
#           70       0.00      0.00      0.00         0
#           71       0.00      0.00      0.00         0
#           72       0.00      0.00      0.00         0
#           73       0.00      0.00      0.00         0
#           74       0.00      0.00      0.00         0
#           75       0.00      0.00      0.00         0
#           76       0.00      0.00      0.00         0
#           77       0.00      0.00      0.00         0
#           78       0.00      0.00      0.00         0
#           79       0.00      0.00      0.00         0
#           80       0.00      0.00      0.00         0
#           81       0.00      0.00      0.00         0
#           82       0.00      0.00      0.00         0
#           83       0.00      0.00      0.00         0
#           84       0.00      0.00      0.00         0
#           85       0.00      0.00      0.00         0
#           86       0.00      0.00      0.00         0
#           87       0.00      0.00      0.00         0
#           88       0.00      0.00      0.00         0
#           89       0.00      0.00      0.00         0
#           90       0.00      0.00      0.00         0
#           91       0.00      0.00      0.00         0
#           92       0.00      0.00      0.00         0
#           93       0.00      0.00      0.00         0
#           94       0.00      0.00      0.00         0
#           95       0.00      0.00      0.00         0
#           96       0.00      0.00      0.00         0
#           97       0.00      0.00      0.00         0
#           98       0.10      0.11      0.10      1281
#           99       0.00      0.00      0.00         0
#          100       0.00      0.00      0.00         0
#          101       0.00      0.00      0.00         0
#          103       0.00      0.00      0.00         0
#          104       0.00      0.00      0.00         0
#          105       0.00      0.00      0.00         0
#          106       0.00      0.00      0.00         0
#          107       0.00      0.00      0.00         0
#          108       0.00      0.00      0.00         0
#          109       0.00      0.00      0.00         0
#          110       0.00      0.00      0.00         0
#          112       0.00      0.00      0.00         0
#          113       0.00      0.00      0.00         0
#          114       0.00      0.00      0.00         0
#          115       0.00      0.00      0.00         0
#          116       0.00      0.00      0.00         0
#          117       0.00      0.00      0.00         0
#          118       0.00      0.00      0.00         0
#          119       0.00      0.00      0.00         0
#          120       0.00      0.00      0.00         0
#          121       0.00      0.00      0.00         0
#          122       0.00      0.00      0.00         0
#          123       0.00      0.00      0.00         0
#          124       0.00      0.00      0.00         0
#          125       0.00      0.00      0.00         0
#          126       0.00      0.00      0.00         0
#          127       0.00      0.00      0.00         0
#          128       0.00      0.00      0.00         0
#          129       0.00      0.00      0.00         0
#
#     accuracy                           0.08     12992
#    macro avg       0.01      0.01      0.01     12992
# weighted avg       0.14      0.08      0.09     12992

# %%
mean_absolute_error(y_pred3, y_test3)
# Out:
# 34.83420566502463

# %%
from sklearn.metrics import accuracy_score
Accuracy3 = accuracy_score(y_pred3, y_test3)
Accuracy3
# Out:
# 0.08235837438423645

# %%
# total accuracy of the model

Mean_Accuracy = (Accuracy1 + Accuracy2 + Accuracy3) / 3
Mean_Accuracy
# Out:
# 0.3122177750410509

# %% [markdown]
# Prediction of Colleges

# %%
pred_College = pd.read_csv("Branch-Prediction.csv")
pred_College.head()
# Out:
#    Unnamed: 0  year institute_type  round_no quota            pool  \
# 0           0  2016            IIT         6    AI  Gender-Neutral
# 1           1  2016            IIT         6    AI  Gender-Neutral
# 2           2  2016            IIT         6    AI  Gender-Neutral
# 3           3  2016            IIT         6    AI  Gender-Neutral
# 4           4  2016            IIT         6    AI  Gender-Neutral
#
#   institute_short           program_name program_duration degree_short  \
# 0      IIT-Bombay  Aerospace Engineering          4 Years       B.Tech
# 1      IIT-Bombay  Aerospace Engineering          4 Years       B.Tech
# 2      IIT-Bombay  Aerospace Engineering          4 Years       B.Tech
# 3      IIT-Bombay  Aerospace Engineering          4 Years       B.Tech
# 4      IIT-Bombay  Aerospace Engineering          4 Years       B.Tech
#
#   category  opening_rank  closing_rank  is_preparatory
# 0      GEN           838          1841               0
# 1  OBC-NCL           408          1098               0
# 2       SC           297           468               0
# 3       ST            79           145               0
# 4  GEN-PWD            94            94               0

# %%
# Changing Institute type

pred_College['institute_type'] = [0 if x == 'IIT' else 1 for x in pred_College['institute_type']]
pred_College['institute_type'].unique()
# Out:
# array([0, 1])

# %%
# Labeling the quota values

le = LabelEncoder()
pred_College['quota'] = le.fit_transform(pred_College['quota'])
pred_College['quota'].unique()
# Out:
# array([0, 3, 6, 1, 2, 4, 5])

# %%
# Labeling the categories

pred_College['category']= le.fit_transform(pred_College['category'])
pred_College['category'].unique()
# Out:
# array([0, 4, 6, 8, 3, 5, 7, 9, 1, 2])

# %%
# Selecting the target data

y1 = pred_College[['institute_short', 'degree_short', 'program_name']]

# %%
# Selecting the featured data

X1 = pred_College[['category', 'quota']]

# %% [markdown]
# Splitting the training and testing data

# %%
# Spilliting the data into training and testing dataset

from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, train_size = 0.8)

# %%
a1 = np.array([X1_train.shape, X1_test.shape, y1_train.shape, y1_test.shape], dtype = 'object')
a1
# Out:
# array([[51966, 2],
#        [12992, 2],
#        [51966, 3],
#        [12992, 3]], dtype=object)

# %% [markdown]
# Generating the model

# %%
# Importing library for mdoel generation

from sklearn.neighbors import KNeighborsClassifier
model1 = KNeighborsClassifier()

# %%
model1.fit(X1_train, y1_train)
# Out:
# KNeighborsClassifier()

# %%
# predicting the dataset

y_pred1 = model1.predict(X1_test)
y_pred1
# Out:
# array([['IIT-Hyderabad', 'B.Tech', 'Architecture'],
#        ['NIT-Jamshedpur', 'B.Tech', 'Civil Engineering'],
#        ['IIT-Jammu', 'B.Tech', 'Mechanical Engineering'],
#        ...,
#        ['NIT-Calicut', 'B.Tech',
#         'Electronics and Communication Engineering'],
#        ['IIT-Jammu', 'B.Tech', 'Mechanical Engineering'],
#        ['IIT-Ropar', 'B.Tech', 'Chemical Engineering']],
#       shape=(12992, 3), dtype=object)

# %%
# prediction

Prediction1 = pd.DataFrame(model1.predict([[0, 0], [5, 5]]), columns = [['College', 'Branch', 'Degree']])
Prediction1
# Out:
#        College  Branch                                     Degree
# 0    IIT-Ropar  B.Tech                       Chemical Engineering
# 1  NIT-Calicut  B.Tech  Electronics and Communication Engineering

# %% [markdown]
# Pickling the model for the deployment

# %%
import pickle

# %%
pickle.dump(model1, open("model1.pkl", "wb"))

# %%
loaded_model = pickle.load(open("model1.pkl", 'rb'))
result = loaded_model.predict([[1, 1]])
print(result)
# Out:
# [['NIT-Warangal' 'B.Tech' 'Bio Technology']]

# %%
result = loaded_model.predict([[0, 6]])
print(result)
# Out:
# [['NIT-Goa' 'B.Tech' 'Computer Science and Engineering']]
